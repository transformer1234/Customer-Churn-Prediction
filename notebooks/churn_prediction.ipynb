# %%
import sys
import os
sys.path.append(os.path.abspath("../"))

from src.model import load_data, preprocess, train_model

df = load_data("../data/Telco-Customer-Churn.csv")
df = preprocess(df)
model, results = train_model(df)

print(results)
# Out:
# {'accuracy': 0.7882018479033405, 'confusion_matrix': array([[930, 103],
#        [195, 179]]), 'classification_report': '              precision    recall  f1-score   support\n\n           0       0.83      0.90      0.86      1033\n           1       0.63      0.48      0.55       374\n\n    accuracy                           0.79      1407\n   macro avg       0.73      0.69      0.70      1407\nweighted avg       0.78      0.79      0.78      1407\n'}
